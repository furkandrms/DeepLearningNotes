# %%
from datasets import load_dataset

# load c4-faq dataset

dataset = load_dataset("vishal-burman/c4-faqs")
print(dataset)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from datasets import load_dataset
#       3 # load c4-faq dataset
# ----> 5 dataset = load_dataset("vishal-burman/c4-faqs")
#       6 print(dataset)
#
# File /opt/homebrew/lib/python3.11/site-packages/datasets/load.py:2549, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2546 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    2548 # Download and prepare data
# -> 2549 builder_instance.download_and_prepare(
#    2550     download_config=download_config,
#    2551     download_mode=download_mode,
#    2552     verification_mode=verification_mode,
# ...
